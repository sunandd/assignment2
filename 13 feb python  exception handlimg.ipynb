# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [raw]
# In Python, when creating a custom exception, it is recommended to inherit from the built-in Exception class or one of its subclasses. The primary reasons for using the Exception class as the base class for custom exceptions are:
#
# Consistent Exception Hierarchy:
#
# The Exception class is at the top of the exception hierarchy in Python. By inheriting from it, you ensure that your custom exception is consistent with the standard exception hierarchy.
# Inheriting from Exception allows your custom exception to be caught by a generic except Exception block, providing a broad catch-all for exceptional situations.
# Compatibility with Existing Exception Handling:
#
# Code that is designed to handle exceptions in a generic way, such as logging or gracefully recovering from errors, can catch instances of the Exception class or any of its subclasses.
# Using the Exception class ensures compatibility with existing exception-handling mechanisms and practices.
# Clarity and Readability:
#
# Inheriting from Exception makes the purpose of your custom exception clear to other developers who might read or maintain your code. It signals that your class represents an exception in the Python exception hierarchy.
# Standard Exception Attributes and Methods:
#
# Inheriting from Exception provides your custom exception with standard attributes like args and methods like __str__. This can be useful for providing additional information about the exception when it is caught and handled.

# %%
class CustomError(Exception):
    def __init__(self, message):
        super().__init__(message)

# Example usage:
try:
    raise CustomError("This is a custom exception.")
except Exception as e:
    print(f"Caught an exception: {e}")
# Out:
# Caught an exception: This is a custom exception.

# %% [raw]
# In this example, CustomError is a custom exception class that inherits from Exception. When an instance of CustomError is raised and caught, it behaves like any other exception, allowing it to be handled in a consistent manner with other exceptions.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 2)

if __name__ == "__main__":
    print("Python Exception Hierarchy:")
    print_exception_hierarchy(Exception)
# Out:
# Python Exception Hierarchy:
# Exception
#   TypeError
#     FloatOperation
#     MultipartConversionError
#   StopAsyncIteration
#   StopIteration
#   ImportError
#     ModuleNotFoundError
#     ZipImportError
#   OSError
#     ConnectionError
#       BrokenPipeError
#       ConnectionAbortedError
#       ConnectionRefusedError
#       ConnectionResetError
#         RemoteDisconnected
#     BlockingIOError
#     ChildProcessError
#     FileExistsError
#     FileNotFoundError
#     IsADirectoryError
#     NotADirectoryError
#     InterruptedError
#       InterruptedSystemCall
#     PermissionError
#     ProcessLookupError
#     TimeoutError
#     UnsupportedOperation
#     itimer_error
#     herror
#     gaierror
#     SSLError
#       SSLCertVerificationError
#       SSLZeroReturnError
#       SSLWantWriteError
#       SSLWantReadError
#       SSLSyscallError
#       SSLEOFError
#     Error
#       SameFileError
#     SpecialFileError
#     ExecError
#     ReadError
#     URLError
# ...

# %% [raw]
# This program defines a function print_exception_hierarchy that takes an exception class and prints its name along with its subclasses in a hierarchical manner. The indent parameter is used for indentation to represent the hierarchy.
#
# In the __main__ block, it calls the function with Exception as the starting point, which is the base class for all exceptions in Python. The output will show the exception hierarchy:

# %% [markdown]
#     Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [raw]
# ArithmeticError is a base class for exceptions that occur during arithmetic operations. Some of the errors defined in the ArithmeticError class include:
#
# FloatingPointError:
#
# Raised when a floating-point operation fails. This typically occurs when performing an invalid operation, such as dividing by zero or taking the square root of a negative number.

# %%
try:
    result = 1.0 / 0.0  # Attempting to divide by zero
except FloatingPointError as fpe:
    print(f"Caught a FloatingPointError: {fpe}")

# %% [raw]
# OverflowError:
#
# Raised when the result of an arithmetic operation exceeds the representable range for the data type. For example, attempting to calculate a value that is too large to fit into an integer or float.

# %%
try:
    result = 2 ** 1000  # Attempting to calculate 2 raised to the power of 1000
except OverflowError as oe:
    print(f"Caught an OverflowError: {oe}")

# %% [raw]
# In this example, the attempt to calculate 2 raised to the power of 1000 results in a number that is too large for Python's integer representation, leading to an OverflowError that is caught in the except block.

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [raw]
# The LookupError class is a base class for exceptions that occur when a key or index used to access a mapping or sequence is invalid. It is a subclass of the more general Exception class. The primary purpose of LookupError is to capture errors related to the lookup of keys or indices.
#
# Two common subclasses of LookupError are KeyError and IndexError. Let's explain each with an example:
#
# KeyError:
#
# Raised when a dictionary key is not found.

# %%
  my_dict = {'a': 1, 'b': 2, 'c': 3}

try:
    value = my_dict['d']  # Attempting to access a non-existent key 'd'
except KeyError as ke:
    print(f"Caught a KeyError: {ke}")
# Out:
# Caught a KeyError: 'd'

# %% [raw]
# In this example, the attempt to access the key 'd' in the dictionary my_dict results in a KeyError. The except block catches the error, and you can handle it accordingly.
#
# IndexError:
#
# Raised when a sequence subscript is out of range.

# %%
my_list = [1, 2, 3]

try:
    value = my_list[5]  # Attempting to access an index that is out of range
except IndexError as ie:
    print(f"Caught an IndexError: {ie}")
# Out:
# Caught an IndexError: list index out of range

# %% [raw]
# In this example, the attempt to access the element at index 5 in the list my_list results in an IndexError. The except block catches the error, allowing you to handle it appropriately.
#
# Both KeyError and IndexError are specific types of lookup errors that fall under the LookupError class. They help you identify and handle situations where keys or indices used for lookup are invalid or out of bounds, providing more controlled and graceful error management in your code.

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [raw]
# ImportError:
# ImportError is an exception raised when the import statement cannot locate the module or when there is an issue with the imported module. It is a base class for various import-related exceptions in Python.

# %%
try:
    import non_existent_module  # Attempting to import a module that doesn't exist
except ImportError as ie:
    print(f"Caught an ImportError: {ie}")
# Out:
# Caught an ImportError: No module named 'non_existent_module'

# %% [raw]
# In this example, the attempt to import a module named non_existent_module that doesn't exist triggers an ImportError. The except block catches the error, and you can handle it, such as providing a fallback or logging a message.
#
# ModuleNotFoundError:
# ModuleNotFoundError is a more specific subclass of ImportError. It is raised when the requested module is not found during the import process.

# %%
try:
    import non_existent_module  # Attempting to import a module that doesn't exist
except ModuleNotFoundError as mne:
    print(f"Caught a ModuleNotFoundError: {mne}")
# Out:
# Caught a ModuleNotFoundError: No module named 'non_existent_module'

# %% [raw]
# In this example, the except block catches the more specific ModuleNotFoundError instead of the more general ImportError. Both exceptions serve a similar purpose, but ModuleNotFoundError provides more information about the nature of the error, specifically indicating that the module could not be found.

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [raw]
# Exception handling is an important aspect of writing robust and maintainable Python code. Here are some best practices for exception handling in Python:
#
# Specificity in Exception Handling:
#
# Be specific in catching exceptions. Avoid using broad except clauses like except Exception: unless you have a compelling reason. This helps in identifying and addressing specific issues.
# Use Try-Except Blocks Sparingly:
#
# Only use try-except blocks where necessary. Don't use them to suppress all errors or to mask bugs. They should be applied selectively to handle specific exceptional situations.
# Avoid Bare Except Clauses:
#
# Avoid using bare except: clauses without specifying the exception type. This can catch unexpected errors and make debugging more challenging. Always catch specific exceptions to handle known issues.
# Handle Exceptions at the Right Level:
#
# Handle exceptions at the appropriate level in your code. This means catching exceptions where you can take meaningful corrective action or provide useful information about the error.
# Logging:
#
# Use logging to record information about exceptions. Logging helps in diagnosing issues during development and monitoring applications in production. Avoid using print statements for debugging in production code.
# Cleanup with Finally:
#
# When cleanup is necessary, use the finally block to ensure that certain code is executed regardless of whether an exception occurred or not. This is useful for resource management.
# Raising Exceptions:
#
# Raise exceptions with informative error messages. Include relevant details in the exception message to aid in debugging. Provide information about what went wrong and why.
# Avoid Excessive Nesting:
#
# Avoid excessive nesting of try-except blocks. Deeply nested blocks can make the code hard to read. Refactor code to simplify nested blocks when possible.
# Custom Exceptions:
#
# Use custom exceptions when appropriate. Create exceptions that convey specific information about errors in your application. This can make your code more readable and maintainable.
# Handle Exceptions Locally:
#
# Handle exceptions as close to the point of occurrence as possible. This improves code readability and makes it easier to understand the context in which an exception is raised.
# Graceful Degradation:
#
# Plan for graceful degradation. Anticipate potential exceptions and design your code to handle them gracefully, allowing the program to continue functioning or fail gracefully without crashing.
# Testing Exceptional Cases:
#
# Write unit tests for exceptional cases. Ensure that your code behaves as expected when exceptions are raised. This helps catch potential issues early in development.
# Remember that effective exception handling is about making your code more robust and providing a better experience for users and developers when errors occur.
